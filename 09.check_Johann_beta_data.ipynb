# %%
import pandas as pd
import anndata
import pickle

# %%
# %%time
f = "./data/Johann_2016/Johann_2016_betas.csv"
df = pd.read_csv(f, index_col=0)
df
# Out:
# CPU times: user 18.6 s, sys: 1.53 s, total: 20.2 s
# Wall time: 20.2 s
#                  GSM1755170_6969568004_R02C01  GSM1755171_6164621144_R04C02  \
# cg00050873                           0.515351                      0.566212
# cg00212031                           0.321033                      0.046125
# cg00213748                           0.579392                      0.056054
# cg00214611                           0.746479                      0.022743
# cg00455876                           0.346311                      0.723831
# ...                                       ...                           ...
# ch.22.909671F                        0.139481                      0.095707
# ch.22.46830341F                      0.076512                      0.051146
# ch.22.1008279F                       0.030666                      0.041098
# ch.22.47579720R                      0.059875                      0.087253
# ...

# %%
with open(x, 'wb') as fh:
    fh.write(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
# ----> 1 with open(x, 'wb') as fh:
#       2     fh.write(df)
#
# NameError: name 'x' is not defined

# %%
adata = anndata.AnnData(df)
adata

# %%
adata.obs

# %%
adata.write("./data/Johann_2016/Johann_2016_betas.h5ad")

# %%
# %%time
anndata.read("./data/Johann_2016/Johann_2016_betas.h5ad")

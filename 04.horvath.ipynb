# %%
import pandas as pd

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM3_ESM.xlsx'
df = pd.read_excel(f, skiprows=2)
df
# Out:
#        Row Human Array ID                              List OnMammalArray  \
# 0        1     cg00075967               Horvath2013.353CpGs           yes
# 1        2     cg00374717               Horvath2013.353CpGs           yes
# 2        3     cg00864867               Horvath2013.353CpGs           yes
# 3        4     cg00945507               Horvath2013.353CpGs           yes
# 4        5     cg01027739               Horvath2013.353CpGs           yes
# ...    ...            ...                               ...           ...
# 2018  2100     cg19015086  SkinAndFibroblastClock233Horvath           yes
# 2019  2102     cg00343092  SkinAndFibroblastClock233Horvath           yes
# 2020  2103     cg27131176  SkinAndFibroblastClock233Horvath           yes
# 2021  2104     cg22982767  SkinAndFibroblastClock233Horvath           yes
# 2022  2105     cg01892695  SkinAndFibroblastClock233Horvath           yes
#
#       mapsToRat  mapsToMouse
# 0             0            0
# ...

# %%
(df['OnMammalArray'] == 'yes').sum()
# Out:
# 1982

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM4_ESM.xlsx'
df = pd.read_excel(f) #, skiprows=2)
df
# Out:
#        Row Human Array ID                              List OnMammalArray  \
# 0        1     cg00075967               Horvath2013.353CpGs           yes
# 1        2     cg00374717               Horvath2013.353CpGs           yes
# 2        3     cg00864867               Horvath2013.353CpGs           yes
# 3        4     cg00945507               Horvath2013.353CpGs           yes
# 4        5     cg01027739               Horvath2013.353CpGs           yes
# ...    ...            ...                               ...           ...
# 2018  2100     cg19015086  SkinAndFibroblastClock233Horvath           yes
# 2019  2102     cg00343092  SkinAndFibroblastClock233Horvath           yes
# 2020  2103     cg27131176  SkinAndFibroblastClock233Horvath           yes
# 2021  2104     cg22982767  SkinAndFibroblastClock233Horvath           yes
# 2022  2105     cg01892695  SkinAndFibroblastClock233Horvath           yes
#
#       mapsToRat  mapsToMouse
# 0             0            0
# ...

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM5_ESM.csv'
df = pd.read_csv(f) #, skiprows=2)
print(df.shape)
df
# Out:
# (38608, 161)
#          Row        CGid  Acinonyx_jubatus.Aci_jub_2_genomic  \
# 0          1  cg00000165          BARHL2_Intergenic_upstream
# 1          2  cg00001209  LOC113603449_Intergenic_downstream
# 2          3  cg00001364                          PROX1_Exon
# 3          4  cg00001582                      ZMIZ1_Promoter
# 4          5  cg00002920           MKI67_Intergenic_upstream
# ...      ...         ...                                 ...
# 38603  38604    34648333                                 NaN
# 38604  38605    41666334                                 NaN
# 38605  38606    43603326                                 NaN
# 38606  38607    39773404                                 NaN
# 38607  38608    42790394                                 NaN
#
#       Ailuropoda_melanoleuca.ailMel1.100  \
# 0             BARHL2_Intergenic_upstream
# 1              KIF2A_Intergenic_upstream
# 2                             PROX1_Exon
# 3                                    NaN
# ...

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM6_ESM.csv'
df = pd.read_csv(f) #, skiprows=2)
print(df.shape)
df
# Out:
# (38608, 120)
#        Unnamed: 0        CGid Acinonyx_jubatus.Aci_jub_2_genomic  \
# 0               1  cg00000165                                 no
# 1               2  cg00001209                                 no
# 2               3  cg00001364                                 no
# 3               4  cg00001582                                 no
# 4               5  cg00002920                                 no
# ...           ...         ...                                ...
# 38603       38604    34648333                                NaN
# 38604       38605    41666334                                NaN
# 38605       38606    43603326                                NaN
# 38606       38607    39773404                                NaN
# 38607       38608    42790394                                NaN
#
#       Ailuropoda_melanoleuca.ailMel1.100  \
# 0                                     no
# 1                                     no
# 2                                     no
# ...

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM7_ESM.xlsx'
df = pd.read_excel(f, skiprows=2)
print(df.shape)
df
# Out:
# (107, 7)
#              Unnamed: 0            Number of CpG bases on the array  \
# 0               all CpG                                       74976
# 1                   NaN                                         NaN
# 2            Annotation  Number of annotated CpG bases on the array
# 3       GERP++ elements                                       71777
# 4    PhastCons elements                                       67479
# ..                  ...                                         ...
# 102    ConsHMM state 96                                           0
# 103    ConsHMM state 97                                           0
# 104    ConsHMM state 98                                           0
# 105    ConsHMM state 99                                           0
# 106   ConsHMM state 100                                          57
#
#                Total number of CpG bases  \
# 0                               56434896
# 1                                    NaN
# ...

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM8_ESM.csv'
df = pd.read_csv(f)#, skiprows=2)
print(df.shape)
df
# Out:
# (38608, 121)
#          Row        CGid highQualityProbesInMouse  CalibrationCor_mouse  \
# 0          1  cg00000165                      NaN              0.484801
# 1          2  cg00001209                      yes              0.986813
# 2          3  cg00001364                      yes              0.980735
# 3          4  cg00001582                      yes              0.906060
# 4          5  cg00002920                      yes              0.967771
# ...      ...         ...                      ...                   ...
# 38603  38604    34648333                      NaN                   NaN
# 38604  38605    41666334                      NaN                   NaN
# 38605  38606    43603326                      NaN                   NaN
# 38606  38607    39773404                      NaN                   NaN
# 38607  38608    42790394                      NaN                   NaN
#
#        CalibrationCor_human  CalibrationCor_rat hg19.SYMBOL  \
# ...

# %%
f = './data/Arneson_Horvath_2022/41467_2022_28355_MOESM9_ESM.csv'
df = pd.read_csv(f)#, skiprows=2)
print(df.shape)
df
# Out:
# (38608, 65)
# /tmp/ipykernel_77294/3985135059.py:2: DtypeWarning: Columns (2,48,49,50,51,52,53,54,55,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)#, skiprows=2)
#            IlmnID                         Name          AddressA_ID  \
# 0      cg00000165  cg00000165_B_C_II_16W28R4_Y             61688267
# 1      cg00001209    cg00001209_B_C_II_15M34_Y             99653471
# 2      cg00001364    cg00001364_B_C_II_28Y21_Y             94653210
# 3      cg00001582    cg00001582_B_C_II_17M32_Y             88781221
# 4      cg00002920  cg00002920_B_C_II_M40Y5Y2_Y              3643387
# ...           ...                          ...                  ...
# 38603    34648333                     Staining            Biotin(0)
# 38604    41666334                     Staining          Biotin(10K)
# 38605    43603326                     Staining               DNP(0)
# 38606    39773404               Target Removal  90_YEAST_3MM_50.1_A
# ...

# %%
f = './data/Arneson_Horvath_2022/Mus_musculus.grcm38.100.HorvathMammalMethylChip40.v1.csv'
df = pd.read_csv(f)
df
# Out:
#        Unnamed: 0        CGid  SYMBOL                  GeneRegionID seqnames  \
# 0               1  cg00000165     NaN                           NaN      NaN
# 1               2  cg00001209  Gm2736    Gm2736_Intergenic_upstream       13
# 2               3  cg00001364   Prox1                    Prox1_Exon        1
# 3               4  cg00001582   Zmiz1                 Zmiz1_fiveUTR       14
# 4               5  cg00002920  Gm9341  Gm9341_Intergenic_downstream        7
# ...           ...         ...     ...                           ...      ...
# 38603       38604    34648333     NaN                           NaN      NaN
# 38604       38605    41666334     NaN                           NaN      NaN
# 38605       38606    43603326     NaN                           NaN      NaN
# 38606       38607    39773404     NaN                           NaN      NaN
# 38607       38608    42790394     NaN                           NaN      NaN
#
# ...

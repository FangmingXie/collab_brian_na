# %%
import pyreadr
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import anndata

from dredFISH.Utils.__init__plots import *

# %% [markdown]
# # load Johann et al

# %%
# metadata
f = './data/Johann_2016/sample_metadata.csv'
meta = pd.read_csv(f, skiprows=2).set_index("Sample Name")

f = './data/Johann_2016/sample_name_map.csv'
nmap = pd.read_csv(f, header=None)
nmap.columns = ['gsm', 'sample']
meta = meta.join(nmap.set_index('sample'))
meta = meta[~meta['gsm'].isnull()]
meta
# Out:
#               Molecular Subgroup (Consensus)  \
# Sample Name
# dkfz_ATRT_1                              SHH
# dkfz_ATRT_2                              SHH
# dkfz_ATRT_3                              SHH
# dkfz_ATRT_4                              MYC
# dkfz_ATRT_5                              SHH
# ...                                      ...
# dkfz_ATRT_146                            SHH
# dkfz_ATRT_147                            SHH
# dkfz_ATRT_148                            SHH
# dkfz_ATRT_149                            SHH
# dkfz_ATRT_150                            SHH
#
#               Subgrouping based on 450K methylation data  \
# Sample Name
# dkfz_ATRT_1                                          SHH
# dkfz_ATRT_2                                          SHH
# dkfz_ATRT_3                                          SHH
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_146                                        SHH
# dkfz_ATRT_147                                        SHH
# dkfz_ATRT_148                                        SHH
# dkfz_ATRT_149                                        SHH
# dkfz_ATRT_150                                        SHH
#
#               Subrouping based on Affymetrix gene expression data  \
# Sample Name
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                                  NaN
# dkfz_ATRT_4                                                  NaN
# dkfz_ATRT_5                                                  NaN
# ...                                                          ...
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
# dkfz_ATRT_148                                                NaN
# dkfz_ATRT_149                                                NaN
# dkfz_ATRT_150                                                NaN
#
#               Subgrouping based on WGBS methylation data  \
# Sample Name
# dkfz_ATRT_1                                          NaN
# dkfz_ATRT_2                                          NaN
# dkfz_ATRT_3                                          NaN
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_146                                        NaN
# dkfz_ATRT_147                                        NaN
# dkfz_ATRT_148                                        NaN
# dkfz_ATRT_149                                        NaN
# dkfz_ATRT_150                                        NaN
#
#               Subgrouping based on H3K27Ac enhancer correlation  WGS cohort  \
# Sample Name
# dkfz_ATRT_1                                                 NaN         NaN
# dkfz_ATRT_2                                                 NaN         NaN
# dkfz_ATRT_3                                                 NaN         NaN
# dkfz_ATRT_4                                                 NaN         1.0
# dkfz_ATRT_5                                                 NaN         1.0
# ...                                                         ...         ...
# dkfz_ATRT_146                                               NaN         NaN
# dkfz_ATRT_147                                               NaN         NaN
# dkfz_ATRT_148                                               NaN         NaN
# dkfz_ATRT_149                                               NaN         NaN
# dkfz_ATRT_150                                               NaN         NaN
#
#                RNASequencing cohort  WGBS cohort  \
# Sample Name
# dkfz_ATRT_1                     NaN          NaN
# dkfz_ATRT_2                     NaN          NaN
# dkfz_ATRT_3                     NaN          NaN
# dkfz_ATRT_4                     NaN          1.0
# dkfz_ATRT_5                     1.0          1.0
# ...                             ...          ...
# dkfz_ATRT_146                   NaN          NaN
# dkfz_ATRT_147                   NaN          NaN
# dkfz_ATRT_148                   NaN          NaN
# dkfz_ATRT_149                   NaN          NaN
# dkfz_ATRT_150                   NaN          NaN
#
#                H3K27Ac ChIP Sequencing cohort  BRD4 ChIP Sequencing cohort  \
# Sample Name
# dkfz_ATRT_1                               NaN                          NaN
# dkfz_ATRT_2                               NaN                          NaN
# dkfz_ATRT_3                               NaN                          NaN
# dkfz_ATRT_4                               NaN                          NaN
# dkfz_ATRT_5                               NaN                          NaN
# ...                                       ...                          ...
# dkfz_ATRT_146                             NaN                          NaN
# dkfz_ATRT_147                             NaN                          NaN
# dkfz_ATRT_148                             NaN                          NaN
# dkfz_ATRT_149                             NaN                          NaN
# dkfz_ATRT_150                             NaN                          NaN
#
#                OTX2 ChIP Sequencing cohort  MITF ChIP Sequencing cohort  \
# Sample Name
# dkfz_ATRT_1                            NaN                          NaN
# dkfz_ATRT_2                            NaN                          NaN
# dkfz_ATRT_3                            NaN                          NaN
# dkfz_ATRT_4                            NaN                          NaN
# dkfz_ATRT_5                            NaN                          NaN
# ...                                    ...                          ...
# dkfz_ATRT_146                          NaN                          NaN
# dkfz_ATRT_147                          NaN                          NaN
# dkfz_ATRT_148                          NaN                          NaN
# dkfz_ATRT_149                          NaN                          NaN
# dkfz_ATRT_150                          NaN                          NaN
#
#               Gender (F= FeMale, M=Male)  Age at diagnosis  \
# Sample Name
# dkfz_ATRT_1                            F              2.00
# dkfz_ATRT_2                            M              2.00
# dkfz_ATRT_3                            F               NaN
# dkfz_ATRT_4                            M              4.00
# dkfz_ATRT_5                            M              4.00
# ...                                  ...               ...
# dkfz_ATRT_146                          M               NaN
# dkfz_ATRT_147                          M               NaN
# dkfz_ATRT_148                          F              0.90
# dkfz_ATRT_149                          M              0.25
# dkfz_ATRT_150                          F              0.80
#
#               Localization of primary tumor  \
# Sample Name
# dkfz_ATRT_1                  infratentorial
# dkfz_ATRT_2                  infratentorial
# dkfz_ATRT_3                  infratentorial
# dkfz_ATRT_4                  infratentorial
# dkfz_ATRT_5                  supratentorial
# ...                                     ...
# dkfz_ATRT_146                supratentorial
# dkfz_ATRT_147                supratentorial
# dkfz_ATRT_148                infratentorial
# dkfz_ATRT_149                supratentorial
# dkfz_ATRT_150                infratentorial
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing   \
# Sample Name
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                       delExon1_Exon9
# dkfz_ATRT_5                                    c.197C>A p.Ser66*
# ...                                                          ...
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
# dkfz_ATRT_148                                            SMARCA4
# dkfz_ATRT_149                                            SMARCA4
# dkfz_ATRT_150                                            SMARCA4
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing  \
# Sample Name
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                     delTBX1_NIPSNAP1
# dkfz_ATRT_5                                     delTBX1_NIPSNAP1
# ...                                                          ...
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
# dkfz_ATRT_148                                                NaN
# dkfz_ATRT_149                                                NaN
# dkfz_ATRT_150                                                NaN
#
#                Previosuly published (PMID number)         gsm
# Sample Name
# dkfz_ATRT_1                                   NaN  GSM1755170
# dkfz_ATRT_2                                   NaN  GSM1755171
# dkfz_ATRT_3                                   NaN  GSM1755172
# dkfz_ATRT_4                                   NaN  GSM1755173
# dkfz_ATRT_5                                   NaN  GSM1755174
# ...                                           ...         ...
# dkfz_ATRT_146                                 NaN  GSM2051701
# dkfz_ATRT_147                                 NaN  GSM2051702
# dkfz_ATRT_148                                 NaN  GSM2051673
# dkfz_ATRT_149                                 NaN  GSM2051674
# dkfz_ATRT_150                                 NaN  GSM2051675
#
# [150 rows x 19 columns]

# %%
# mc data
f = "./data/Johann_2016/Johann_2016_betas.h5ad"
adata = anndata.read(f)
adata
# Out:
# AnnData object with n_obs × n_vars = 485512 × 150

# %%
name_lookup = meta.reset_index().set_index('gsm')['Sample Name']
adata.var.index = [name_lookup.loc[samp.split('_')[0]] for samp in adata.var.index]
adata.var = meta.loc[adata.var.index]
adata.var
# Out:
#               Molecular Subgroup (Consensus)  \
# dkfz_ATRT_1                              SHH
# dkfz_ATRT_2                              SHH
# dkfz_ATRT_3                              SHH
# dkfz_ATRT_4                              MYC
# dkfz_ATRT_5                              SHH
# ...                                      ...
# dkfz_ATRT_143                            SHH
# dkfz_ATRT_144                            MYC
# dkfz_ATRT_145                            SHH
# dkfz_ATRT_146                            SHH
# dkfz_ATRT_147                            SHH
#
#               Subgrouping based on 450K methylation data  \
# dkfz_ATRT_1                                          SHH
# dkfz_ATRT_2                                          SHH
# dkfz_ATRT_3                                          SHH
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_143                                        SHH
# dkfz_ATRT_144                                        MYC
# dkfz_ATRT_145                                        SHH
# dkfz_ATRT_146                                        SHH
# dkfz_ATRT_147                                        SHH
#
#               Subrouping based on Affymetrix gene expression data  \
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                                  NaN
# dkfz_ATRT_4                                                  NaN
# dkfz_ATRT_5                                                  NaN
# ...                                                          ...
# dkfz_ATRT_143                                                NaN
# dkfz_ATRT_144                                                NaN
# dkfz_ATRT_145                                                NaN
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
#
#               Subgrouping based on WGBS methylation data  \
# dkfz_ATRT_1                                          NaN
# dkfz_ATRT_2                                          NaN
# dkfz_ATRT_3                                          NaN
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_143                                        NaN
# dkfz_ATRT_144                                        NaN
# dkfz_ATRT_145                                        NaN
# dkfz_ATRT_146                                        NaN
# dkfz_ATRT_147                                        NaN
#
#               Subgrouping based on H3K27Ac enhancer correlation  WGS cohort  \
# dkfz_ATRT_1                                                 NaN         NaN
# dkfz_ATRT_2                                                 NaN         NaN
# dkfz_ATRT_3                                                 NaN         NaN
# dkfz_ATRT_4                                                 NaN         1.0
# dkfz_ATRT_5                                                 NaN         1.0
# ...                                                         ...         ...
# dkfz_ATRT_143                                               NaN         NaN
# dkfz_ATRT_144                                               NaN         NaN
# dkfz_ATRT_145                                               NaN         NaN
# dkfz_ATRT_146                                               NaN         NaN
# dkfz_ATRT_147                                               NaN         NaN
#
#                RNASequencing cohort  WGBS cohort  \
# dkfz_ATRT_1                     NaN          NaN
# dkfz_ATRT_2                     NaN          NaN
# dkfz_ATRT_3                     NaN          NaN
# dkfz_ATRT_4                     NaN          1.0
# dkfz_ATRT_5                     1.0          1.0
# ...                             ...          ...
# dkfz_ATRT_143                   NaN          NaN
# dkfz_ATRT_144                   NaN          NaN
# dkfz_ATRT_145                   NaN          NaN
# dkfz_ATRT_146                   NaN          NaN
# dkfz_ATRT_147                   NaN          NaN
#
#                H3K27Ac ChIP Sequencing cohort  BRD4 ChIP Sequencing cohort  \
# dkfz_ATRT_1                               NaN                          NaN
# dkfz_ATRT_2                               NaN                          NaN
# dkfz_ATRT_3                               NaN                          NaN
# dkfz_ATRT_4                               NaN                          NaN
# dkfz_ATRT_5                               NaN                          NaN
# ...                                       ...                          ...
# dkfz_ATRT_143                             NaN                          NaN
# dkfz_ATRT_144                             NaN                          NaN
# dkfz_ATRT_145                             NaN                          NaN
# dkfz_ATRT_146                             NaN                          NaN
# dkfz_ATRT_147                             NaN                          NaN
#
#                OTX2 ChIP Sequencing cohort  MITF ChIP Sequencing cohort  \
# dkfz_ATRT_1                            NaN                          NaN
# dkfz_ATRT_2                            NaN                          NaN
# dkfz_ATRT_3                            NaN                          NaN
# dkfz_ATRT_4                            NaN                          NaN
# dkfz_ATRT_5                            NaN                          NaN
# ...                                    ...                          ...
# dkfz_ATRT_143                          NaN                          NaN
# dkfz_ATRT_144                          NaN                          NaN
# dkfz_ATRT_145                          NaN                          NaN
# dkfz_ATRT_146                          NaN                          NaN
# dkfz_ATRT_147                          NaN                          NaN
#
#               Gender (F= FeMale, M=Male)  Age at diagnosis  \
# dkfz_ATRT_1                            F               2.0
# dkfz_ATRT_2                            M               2.0
# dkfz_ATRT_3                            F               NaN
# dkfz_ATRT_4                            M               4.0
# dkfz_ATRT_5                            M               4.0
# ...                                  ...               ...
# dkfz_ATRT_143                          M               NaN
# dkfz_ATRT_144                          F               NaN
# dkfz_ATRT_145                          M               NaN
# dkfz_ATRT_146                          M               NaN
# dkfz_ATRT_147                          M               NaN
#
#               Localization of primary tumor  \
# dkfz_ATRT_1                  infratentorial
# dkfz_ATRT_2                  infratentorial
# dkfz_ATRT_3                  infratentorial
# dkfz_ATRT_4                  infratentorial
# dkfz_ATRT_5                  supratentorial
# ...                                     ...
# dkfz_ATRT_143                infratentorial
# dkfz_ATRT_144                           NaN
# dkfz_ATRT_145                           NaN
# dkfz_ATRT_146                supratentorial
# dkfz_ATRT_147                supratentorial
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing   \
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                       delExon1_Exon9
# dkfz_ATRT_5                                    c.197C>A p.Ser66*
# ...                                                          ...
# dkfz_ATRT_143                                                NaN
# dkfz_ATRT_144                                                NaN
# dkfz_ATRT_145                                                NaN
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing  \
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                     delTBX1_NIPSNAP1
# dkfz_ATRT_5                                     delTBX1_NIPSNAP1
# ...                                                          ...
# dkfz_ATRT_143                                                NaN
# dkfz_ATRT_144                                                NaN
# dkfz_ATRT_145                                                NaN
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
#
#                Previosuly published (PMID number)         gsm
# dkfz_ATRT_1                                   NaN  GSM1755170
# dkfz_ATRT_2                                   NaN  GSM1755171
# dkfz_ATRT_3                                   NaN  GSM1755172
# dkfz_ATRT_4                                   NaN  GSM1755173
# dkfz_ATRT_5                                   NaN  GSM1755174
# ...                                           ...         ...
# dkfz_ATRT_143                                 NaN  GSM2051698
# dkfz_ATRT_144                                 NaN  GSM2051699
# dkfz_ATRT_145                                 NaN  GSM2051700
# dkfz_ATRT_146                                 NaN  GSM2051701
# dkfz_ATRT_147                                 NaN  GSM2051702
#
# [150 rows x 19 columns]

# %%
colors = sns.color_palette('Set1', 3)
colors
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726)]

# %%
palette = {
    'TYR': colors[0],
    'SHH': colors[1],
    'MYC': colors[2],
}

# %%
clsts = adata.var['Subgrouping based on 450K methylation data'].values
clsts
# Out:
# array(['SHH', 'SHH', 'SHH', 'MYC', 'SHH', 'TYR', 'SHH', 'TYR', 'SHH',
#        'TYR', 'SHH', 'SHH', 'MYC', 'TYR', 'SHH', 'TYR', 'SHH', 'SHH',
#        'SHH', 'SHH', 'SHH', 'TYR', 'TYR', 'TYR', 'TYR', 'MYC', 'MYC',
#        'TYR', 'SHH', 'TYR', 'SHH', 'SHH', 'TYR', 'TYR', 'SHH', 'SHH',
#        'MYC', 'SHH', 'SHH', 'TYR', 'MYC', 'SHH', 'MYC', 'SHH', 'SHH',
#        'MYC', 'TYR', 'TYR', 'MYC', 'MYC', 'SHH', 'TYR', 'MYC', 'SHH',
#        'SHH', 'SHH', 'TYR', 'TYR', 'MYC', 'SHH', 'TYR', 'TYR', 'MYC',
#        'MYC', 'MYC', 'TYR', 'TYR', 'SHH', 'MYC', 'TYR', 'MYC', 'SHH',
#        'TYR', 'SHH', 'SHH', 'TYR', 'MYC', 'TYR', 'SHH', 'TYR', 'SHH',
#        'MYC', 'TYR', 'TYR', 'TYR', 'SHH', 'TYR', 'MYC', 'MYC', 'MYC',
#        'MYC', 'TYR', 'TYR', 'TYR', 'TYR', 'MYC', 'SHH', 'TYR', 'TYR',
#        'TYR', 'TYR', 'SHH', 'SHH', 'MYC', 'SHH', 'SHH', 'SHH', 'SHH',
#        'SHH', 'TYR', 'SHH', 'TYR', 'SHH', 'SHH', 'MYC', 'SHH', 'SHH',
#        'SHH', 'MYC', 'SHH', 'SHH', 'SHH', 'SHH', 'SHH', 'MYC', 'MYC',
#        'TYR', 'SHH', 'TYR', 'TYR', 'SHH', 'TYR', 'TYR', 'TYR', 'TYR',
#        'MYC', 'SHH', 'TYR', 'MYC', 'TYR', 'MYC', 'SHH', 'TYR', 'SHH',
#        'SHH', 'SHH', 'MYC', 'SHH', 'SHH', 'SHH'], dtype=object)

# %%
hps = adata.obs.index.values
hps
# Out:
# array(['cg00050873', 'cg00212031', 'cg00213748', ..., 'ch.22.1008279F',
#        'ch.22.47579720R', 'ch.22.48274842R'], dtype=object)

# %% [markdown]
# # load our data

# %%
f = 'SamplesheetAgeP39final.csv'
meta_m = pd.read_csv(f)
meta_m
# Out:
#     OriginalOrderInBatch ExternalSampleID             Basename       Age  \
# 0                      1       20147-9 #1  206535570066_R05C02  0.333333
# 1                      2       20207-9 #1  206535570066_R06C02  0.416667
# 2                      3       17016-9 #1  206535570010_R01C01  0.391667
# 3                      4      17100-9B #1  206535570010_R02C01  0.275000
# 4                      5     18161-10B #1  206535570010_R03C01  0.308333
# 5                      6      20074-9B #1  206535570010_R04C01  0.300000
# 6                      7       20095-9 #1  206535570010_R05C01  0.416667
# 7                      8       20137-9 #1  206535570010_R06C01  0.258333
# 8                      9       20142-9 #1  206535570010_R01C02  0.366667
# 9                     10       20191-9 #1  206535570010_R02C02  0.400000
# 10                    11       20101-9 #1  206535570010_R03C02  0.141667
# 11                    12        9257-9 #1  206535570010_R04C02  0.241667
#
#     ConfidenceInAgeEstimate CanBeUsedForAgingStudies SpeciesLatinName  \
# 0                       100                      yes     Mus musculus
# 1                       100                      yes     Mus musculus
# 2                       100                      yes     Mus musculus
# 3                       100                      yes     Mus musculus
# 4                       100                      yes     Mus musculus
# 5                       100                      yes     Mus musculus
# 6                       100                      yes     Mus musculus
# 7                       100                      yes     Mus musculus
# 8                       100                      yes     Mus musculus
# 9                       100                      yes     Mus musculus
# 10                      100                      yes     Mus musculus
# 11                      100                      yes     Mus musculus
#
#    SpeciesCommonName            Tissue  Female  ...  \
# 0              Mouse    Olfactory Bulb       0  ...
# 1              Mouse    Olfactory Bulb       1  ...
# 2              Mouse  Trigeminal nerve       1  ...
# 3              Mouse          Meninges       0  ...
# 4              Mouse  Trigeminal nerve       1  ...
# 5              Mouse     Retro-orbital       1  ...
# 6              Mouse       Optic nerve       0  ...
# 7              Mouse    Olfactory bulb       0  ...
# 8              Mouse      Nasal cavity       1  ...
# 9              Mouse            Throat       1  ...
# 10             Mouse      Nasal cavity       1  ...
# 11             Mouse     Retro-orbital       1  ...
#
#    Steve.InterventionClock.AgeTraf.Cortex.clock.epiAge  \
# 0                                            4.033001
# 1                                            3.847563
# 2                                            3.447378
# 3                                            2.556212
# 4                                            4.328767
# 5                                            5.105332
# 6                                            2.409617
# 7                                            3.407836
# 8                                            3.945867
# 9                                            5.342979
# 10                                           2.527495
# 11                                           1.519241
#
#    Steve.InterventionClock.AgeTraf.Fibroblast.clock.epiAge  \
# 0                                            4.926304
# 1                                            1.656940
# 2                                            2.460107
# 3                                            1.965027
# 4                                            6.060459
# 5                                            2.609845
# 6                                            0.126154
# 7                                            0.888272
# 8                                            2.776968
# 9                                            4.463271
# 10                                           0.289263
# 11                                           3.320867
#
#    Steve.InterventionClock.AgeTraf.Heart.clock.epiAge  \
# 0                                            0.842963
# 1                                            0.257613
# 2                                           -0.041745
# 3                                           -0.058308
# 4                                           -0.016699
# 5                                            0.132868
# 6                                           -0.020210
# 7                                            0.304209
# 8                                            1.454515
# 9                                            0.928019
# 10                                          -0.051218
# 11                                           1.833316
#
#    Steve.InterventionClock.AgeTraf.Kidney.clock.epiAge  \
# 0                                            1.900062
# 1                                            2.984474
# 2                                            0.386455
# 3                                            2.483933
# 4                                            3.926171
# 5                                            0.668717
# 6                                            0.163322
# 7                                            1.353959
# 8                                            2.627008
# 9                                            0.044868
# 10                                           0.600396
# 11                                           0.341087
#
#    Steve.InterventionClock.AgeTraf.Liver.clock.epiAge  \
# 0                                            0.269345
# 1                                            0.363235
# 2                                            0.360516
# 3                                            0.127727
# 4                                            0.505825
# 5                                            0.432172
# 6                                            0.205064
# 7                                            0.223376
# 8                                            0.435729
# 9                                            0.346802
# 10                                           0.124975
# 11                                           0.434660
#
#    Steve.InterventionClock.AgeTraf.Muscle.clock.epiAge  \
# 0                                            2.317238
# 1                                            1.440735
# 2                                            2.363680
# 3                                            1.599632
# 4                                            3.300223
# 5                                            1.498241
# 6                                            0.421941
# 7                                            0.726891
# 8                                            3.059793
# 9                                            3.442907
# 10                                           0.275663
# 11                                           2.169974
#
#    Steve.InterventionClock.AgeTraf.panTissue.clock.epiAge  \
# 0                                            0.149250
# 1                                            1.012970
# 2                                            0.459224
# 3                                            0.273974
# 4                                            0.165580
# 5                                            0.568705
# 6                                            0.543390
# 7                                            0.534108
# 8                                            0.680205
# 9                                            0.200563
# 10                                           0.055411
# 11                                           0.325413
#
#    Steve.InterventionClock.AgeTraf.Skin.clock.epiAge  \
# 0                                           0.662770
# 1                                           0.485708
# 2                                           0.400640
# 3                                           0.232241
# 4                                           0.695521
# 5                                           0.620582
# 6                                           0.260301
# 7                                           0.285111
# 8                                           0.646078
# 9                                           0.687147
# 10                                          0.061597
# 11                                          0.736978
#
#    Steve.InterventionClock.AgeTraf.Striatum.clock.epiAge  \
# 0                                            4.115116
# 1                                            4.394053
# 2                                            5.752594
# 3                                            5.726338
# 4                                            1.290540
# 5                                            2.912459
# 6                                            1.648521
# 7                                            2.566658
# 8                                            4.466324
# 9                                            5.833257
# 10                                           2.833229
# 11                                           2.182974
#
#     Steve.InterventionClock.AgeTraf.Tail.clock.epiAge
# 0                                            0.536970
# 1                                            1.194265
# 2                                            1.929016
# 3                                            2.257875
# 4                                            0.561456
# 5                                            0.426205
# 6                                            0.348279
# 7                                            0.646184
# 8                                            0.501263
# 9                                            0.548300
# 10                                           0.410801
# 11                                           0.770701
#
# [12 rows x 229 columns]

# %%
f = "all_probes_sesame_normalized.RDS" 
data_m = pyreadr.read_r(f)[None]
data_m = data_m.T
data_m
# Out:
#                  206535570066_R05C02  206535570066_R06C02  \
# cg00000165_TC21             0.464574             0.483712
# cg00001209_TC21             0.709015             0.647783
# cg00001364_TC21             0.749347             0.914103
# cg00001582_TC21             0.054638             0.054335
# cg00002920_TC21             0.199709             0.117025
# ...                              ...                  ...
# rs877309_BC21               0.473372             0.546911
# rs9292570_BC11              0.495280             0.503069
# rs9363764_BC21              0.515029             0.459686
# rs951295_BC11               0.056931             0.044640
# rs9839873_BC21              0.492508             0.470668
#
#                  206535570010_R01C01  206535570010_R02C01  \
# cg00000165_TC21             0.485698             0.512629
# cg00001209_TC21             0.642106             0.558514
# cg00001364_TC21             0.914649             0.516546
# cg00001582_TC21             0.053501             0.081808
# cg00002920_TC21             0.298558             0.272371
# ...                              ...                  ...
# rs877309_BC21               0.511721             0.494019
# rs9292570_BC11              0.504700             0.506527
# rs9363764_BC21              0.519578             0.508826
# rs951295_BC11               0.060683             0.060909
# rs9839873_BC21              0.470023             0.500726
#
#                  206535570010_R03C01  206535570010_R04C01  \
# cg00000165_TC21             0.488281             0.490644
# cg00001209_TC21             0.670084             0.668659
# cg00001364_TC21             0.899112             0.916861
# cg00001582_TC21             0.057557             0.062748
# cg00002920_TC21             0.214564             0.189437
# ...                              ...                  ...
# rs877309_BC21               0.515623             0.496569
# rs9292570_BC11              0.522663             0.530290
# rs9363764_BC21              0.486397             0.479303
# rs951295_BC11               0.055960             0.059086
# rs9839873_BC21              0.477591             0.534594
#
#                  206535570010_R05C01  206535570010_R06C01  \
# cg00000165_TC21             0.496566             0.491678
# cg00001209_TC21             0.692513             0.789740
# cg00001364_TC21             0.748892             0.912464
# cg00001582_TC21             0.038457             0.051540
# cg00002920_TC21             0.321178             0.354263
# ...                              ...                  ...
# rs877309_BC21               0.520476             0.518697
# rs9292570_BC11              0.512177             0.484462
# rs9363764_BC21              0.455853             0.487021
# rs951295_BC11               0.056436             0.049847
# rs9839873_BC21              0.505198             0.483725
#
#                  206535570010_R01C02  206535570010_R02C02  \
# cg00000165_TC21             0.485013             0.442666
# cg00001209_TC21             0.638012             0.240190
# cg00001364_TC21             0.913994             0.920995
# cg00001582_TC21             0.060898             0.036618
# cg00002920_TC21             0.193437             0.308441
# ...                              ...                  ...
# rs877309_BC21               0.567449             0.480997
# rs9292570_BC11              0.496929             0.480304
# rs9363764_BC21              0.467514             0.541826
# rs951295_BC11               0.047304             0.047698
# rs9839873_BC21              0.522440             0.515825
#
#                  206535570010_R03C02  206535570010_R04C02
# cg00000165_TC21             0.507296             0.465939
# cg00001209_TC21             0.714195             0.696545
# cg00001364_TC21             0.818239             0.859054
# cg00001582_TC21             0.067346             0.061484
# cg00002920_TC21             0.354261             0.384626
# ...                              ...                  ...
# rs877309_BC21               0.516118             0.508063
# rs9292570_BC11              0.445632             0.487827
# rs9363764_BC21              0.511584             0.463032
# rs951295_BC11               0.076089             0.071503
# rs9839873_BC21              0.473433             0.482658
#
# [326732 rows x 12 columns]

# %%
m_probes = data_m.index.values
mps = np.array([p.split('_')[0] for p in m_probes]) # may be duplicated
print(mps.shape, np.unique(mps).shape)

ops = np.load('./data/m320k_i450k_overlap_5559.npy')
cps = np.intersect1d(mps, hps)
print(mps.shape, hps.shape, ops.shape, cps.shape)
# Out:
# (326732,) (319280,)
# (326732,) (485512,) (5559,) (5500,)

# %%
mdf = data_m.copy()
mdf.index = mps
mdf = mdf[~mdf.index.duplicated(keep='first')] # a hack
mps = mdf.index.values
print(mps.shape)
mdf
# Out:
# (319280,)
#             206535570066_R05C02  206535570066_R06C02  206535570010_R01C01  \
# cg00000165             0.464574             0.483712             0.485698
# cg00001209             0.709015             0.647783             0.642106
# cg00001364             0.749347             0.914103             0.914649
# cg00001582             0.054638             0.054335             0.053501
# cg00002920             0.199709             0.117025             0.298558
# ...                         ...                  ...                  ...
# rs877309               0.473372             0.546911             0.511721
# rs9292570              0.495280             0.503069             0.504700
# rs9363764              0.515029             0.459686             0.519578
# rs951295               0.056931             0.044640             0.060683
# rs9839873              0.492508             0.470668             0.470023
#
#             206535570010_R02C01  206535570010_R03C01  206535570010_R04C01  \
# cg00000165             0.512629             0.488281             0.490644
# cg00001209             0.558514             0.670084             0.668659
# cg00001364             0.516546             0.899112             0.916861
# cg00001582             0.081808             0.057557             0.062748
# cg00002920             0.272371             0.214564             0.189437
# ...                         ...                  ...                  ...
# rs877309               0.494019             0.515623             0.496569
# rs9292570              0.506527             0.522663             0.530290
# rs9363764              0.508826             0.486397             0.479303
# rs951295               0.060909             0.055960             0.059086
# rs9839873              0.500726             0.477591             0.534594
#
#             206535570010_R05C01  206535570010_R06C01  206535570010_R01C02  \
# cg00000165             0.496566             0.491678             0.485013
# cg00001209             0.692513             0.789740             0.638012
# cg00001364             0.748892             0.912464             0.913994
# cg00001582             0.038457             0.051540             0.060898
# cg00002920             0.321178             0.354263             0.193437
# ...                         ...                  ...                  ...
# rs877309               0.520476             0.518697             0.567449
# rs9292570              0.512177             0.484462             0.496929
# rs9363764              0.455853             0.487021             0.467514
# rs951295               0.056436             0.049847             0.047304
# rs9839873              0.505198             0.483725             0.522440
#
#             206535570010_R02C02  206535570010_R03C02  206535570010_R04C02
# cg00000165             0.442666             0.507296             0.465939
# cg00001209             0.240190             0.714195             0.696545
# cg00001364             0.920995             0.818239             0.859054
# cg00001582             0.036618             0.067346             0.061484
# cg00002920             0.308441             0.354261             0.384626
# ...                         ...                  ...                  ...
# rs877309               0.480997             0.516118             0.508063
# rs9292570              0.480304             0.445632             0.487827
# rs9363764              0.541826             0.511584             0.463032
# rs951295               0.047698             0.076089             0.071503
# rs9839873              0.515825             0.473433             0.482658
#
# [319280 rows x 12 columns]

# %%
df_m = mdf.loc[cps]
df_m
# Out:
#                  206535570066_R05C02  206535570066_R06C02  \
# cg00000165                  0.464574             0.483712
# cg00001364                  0.749347             0.914103
# cg00001582                  0.054638             0.054335
# cg00003994                  0.038456             0.030914
# cg00005112                  0.770640             0.651730
# ...                              ...                  ...
# cg27664614                  0.500484             0.519151
# ch.12.1107853R              0.478633             0.503359
# ch.13.39564907R             0.519924             0.503823
# ch.2.30415474F              0.500492             0.476220
# ch.3.741789F                0.495479             0.505096
#
#                  206535570010_R01C01  206535570010_R02C01  \
# cg00000165                  0.485698             0.512629
# cg00001364                  0.914649             0.516546
# cg00001582                  0.053501             0.081808
# cg00003994                  0.040603             0.039053
# cg00005112                  0.478689             0.821402
# ...                              ...                  ...
# cg27664614                  0.475230             0.498556
# ch.12.1107853R              0.491460             0.511703
# ch.13.39564907R             0.499999             0.545625
# ch.2.30415474F              0.498826             0.485673
# ch.3.741789F                0.446132             0.449461
#
#                  206535570010_R03C01  206535570010_R04C01  \
# cg00000165                  0.488281             0.490644
# cg00001364                  0.899112             0.916861
# cg00001582                  0.057557             0.062748
# cg00003994                  0.043289             0.042252
# cg00005112                  0.587515             0.760703
# ...                              ...                  ...
# cg27664614                  0.471068             0.485931
# ch.12.1107853R              0.514017             0.485483
# ch.13.39564907R             0.504760             0.494526
# ch.2.30415474F              0.487613             0.484506
# ch.3.741789F                0.485002             0.498230
#
#                  206535570010_R05C01  206535570010_R06C01  \
# cg00000165                  0.496566             0.491678
# cg00001364                  0.748892             0.912464
# cg00001582                  0.038457             0.051540
# cg00003994                  0.034478             0.025306
# cg00005112                  0.585092             0.736821
# ...                              ...                  ...
# cg27664614                  0.542657             0.527555
# ch.12.1107853R              0.498080             0.469606
# ch.13.39564907R             0.506781             0.496763
# ch.2.30415474F              0.505012             0.492147
# ch.3.741789F                0.504632             0.462482
#
#                  206535570010_R01C02  206535570010_R02C02  \
# cg00000165                  0.485013             0.442666
# cg00001364                  0.913994             0.920995
# cg00001582                  0.060898             0.036618
# cg00003994                  0.048871             0.034659
# cg00005112                  0.659390             0.258120
# ...                              ...                  ...
# cg27664614                  0.518164             0.543017
# ch.12.1107853R              0.518160             0.460934
# ch.13.39564907R             0.513498             0.509771
# ch.2.30415474F              0.559146             0.494005
# ch.3.741789F                0.468776             0.500000
#
#                  206535570010_R03C02  206535570010_R04C02
# cg00000165                  0.507296             0.465939
# cg00001364                  0.818239             0.859054
# cg00001582                  0.067346             0.061484
# cg00003994                  0.027721             0.035719
# cg00005112                  0.646212             0.493449
# ...                              ...                  ...
# cg27664614                  0.499005             0.466139
# ch.12.1107853R              0.500000             0.511801
# ch.13.39564907R             0.454124             0.509854
# ch.2.30415474F              0.481147             0.474381
# ch.3.741789F                0.482511             0.468379
#
# [5500 rows x 12 columns]

# %%
sns.histplot(df_m.std(axis=1))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.clustermap(df_m, cmap='coolwarm', figsize=(10,15), vmin=0, vmax=1)
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
df_m_hv = df_m[df_m.std(axis=1)>0.1].copy()
print(df_m_hv.shape)
sns.clustermap(df_m_hv, cmap='coolwarm', figsize=(10,15), vmin=0, vmax=1)
# Out:
# (571, 12)

# %%
df_m_hv = df_m[df_m.std(axis=1)>0.15].copy()
print(df_m_hv.shape)
sns.clustermap(df_m_hv, cmap='coolwarm', figsize=(10,15), vmin=0, vmax=1)
# Out:
# (156, 12)

# %%
df_m_hv = df_m[df_m.std(axis=1)>0.2].copy()
print(df_m_hv.shape)
sns.clustermap(df_m_hv, cmap='coolwarm', figsize=(10,15), vmin=0, vmax=1)
# Out:
# (21, 12)

# %%
adata_h = adata[cps]
adata_h
# Out:
# View of AnnData object with n_obs × n_vars = 5500 × 150
#     var: 'Molecular Subgroup (Consensus)', 'Subgrouping based on 450K methylation data', 'Subrouping based on Affymetrix gene expression data', 'Subgrouping based on WGBS methylation data', 'Subgrouping based on H3K27Ac enhancer correlation', 'WGS cohort', 'RNASequencing cohort', 'WGBS cohort', 'H3K27Ac ChIP Sequencing cohort', 'BRD4 ChIP Sequencing cohort', 'OTX2 ChIP Sequencing cohort', 'MITF ChIP Sequencing cohort', 'Gender (F= FeMale, M=Male)', 'Age at diagnosis', 'Localization of primary tumor', 'Type of SMARCB1 mutation in MLPA/Sanger Sequencing ', 'Type of SMARCB1 mutation in MLPA/Sanger Sequencing', 'Previosuly published (PMID number)', 'gsm'

# %%
np.all(df_m.index.values == adata_h.obs.index.values)
# Out:
# True

# %%
df_h = pd.DataFrame(adata_h.X, index=adata_h.obs.index)
print(df_h.shape)
df_h = df_h[~np.any(np.isnan(df_h), axis=1)]
print(df_h.shape)

sites_std = df_h.std(axis=1, ddof=0)
th = 0.2
cond = sites_std > th
df_h_hv = df_h[cond]
df_m_hv = df_m.loc[df_h_hv.index]
print(df_h_hv.shape, df_m_hv.shape)
# Out:
# (5500, 150)
# (5489, 150)
# (466, 150) (466, 12)

# %%
import scipy.cluster.hierarchy as sch
rl_h = sch.linkage(df_h_hv.values, method='average')
cl_h = sch.linkage(df_h_hv.values.T, method='average')

# %%
rord_h = np.array(sch.dendrogram(rl_h, no_plot=True)['leaves'])
cord_h = np.array(sch.dendrogram(cl_h, no_plot=True)['leaves'])

# %%
np.arange(0,len(rord_h),100)
# Out:
# array([  0, 100, 200, 300, 400])

# %%
with sns.axes_style('white'):
    fig, axs = plt.subplots(1,2,figsize=(2*6,1*12), sharey=False)
    ax = axs[0]
    sns.heatmap(
        df_h_hv.values[rord_h][:,cord_h],
        yticklabels=100,
        cmap='coolwarm', 
        cbar_kws=dict(shrink=0.3),
        cbar=False,
        vmax=1, vmin=0, 
        ax=ax)
    ax.set_title('Illu. 450k array - human\n(Johann et al. 2016)')
    ax.set_ylabel(f'{len(rord_h)} sites')

    ax = axs[1]
    sns.heatmap(
        df_m_hv.values[rord_h], #[:,cord_h],
        yticklabels=100,
        cmap='coolwarm', 
        cbar_kws=dict(shrink=0.3),
        vmax=1, vmin=0, 
        ax=ax)
    ax.set_title('Mammal 320k array - mouse\n(Vitte et al. 2017)')
    ax.set_ylabel(f'The same {len(rord_h)} orthologous sites')

# %%
sns.clustermap(df_h_hv.values, 
               row_linkage=rl_h, 
               col_linkage=cl_h, 
               col_colors=pd.Series(clsts).map(palette).values,
               cmap='coolwarm', 
               vmax=1, vmin=0,
              )

# %%
sns.clustermap(df_m_hv.values, 
               row_linkage=rl_h, 
               # col_colors=pd.Series(clsts).map(palette).values,
               cmap='coolwarm', 
               vmax=1, vmin=0,
              )

# %%
sns.clustermap(df_m_hv.values, 
               # row_linkage=rl_h, 
               # col_colors=pd.Series(clsts).map(palette).values,
               cmap='coolwarm', 
               vmax=1, vmin=0,
              )

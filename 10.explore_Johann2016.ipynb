# %%
import pandas as pd
import numpy as np
import anndata

from dredFISH.Utils.__init__plots import *
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
# metadata
f = './data/Johann_2016/sample_metadata.csv'
meta = pd.read_csv(f, skiprows=2).set_index("Sample Name")

f = './data/Johann_2016/sample_name_map.csv'
nmap = pd.read_csv(f, header=None)
nmap.columns = ['gsm', 'sample']
meta = meta.join(nmap.set_index('sample'))
meta = meta[~meta['gsm'].isnull()]
meta
# Out:
#               Molecular Subgroup (Consensus)  \
# Sample Name
# dkfz_ATRT_1                              SHH
# dkfz_ATRT_2                              SHH
# dkfz_ATRT_3                              SHH
# dkfz_ATRT_4                              MYC
# dkfz_ATRT_5                              SHH
# ...                                      ...
# dkfz_ATRT_146                            SHH
# dkfz_ATRT_147                            SHH
# dkfz_ATRT_148                            SHH
# dkfz_ATRT_149                            SHH
# dkfz_ATRT_150                            SHH
#
#               Subgrouping based on 450K methylation data  \
# Sample Name
# dkfz_ATRT_1                                          SHH
# dkfz_ATRT_2                                          SHH
# dkfz_ATRT_3                                          SHH
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_146                                        SHH
# dkfz_ATRT_147                                        SHH
# dkfz_ATRT_148                                        SHH
# dkfz_ATRT_149                                        SHH
# dkfz_ATRT_150                                        SHH
#
#               Subrouping based on Affymetrix gene expression data  \
# Sample Name
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                                  NaN
# dkfz_ATRT_4                                                  NaN
# dkfz_ATRT_5                                                  NaN
# ...                                                          ...
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
# dkfz_ATRT_148                                                NaN
# dkfz_ATRT_149                                                NaN
# dkfz_ATRT_150                                                NaN
#
#               Subgrouping based on WGBS methylation data  \
# Sample Name
# dkfz_ATRT_1                                          NaN
# dkfz_ATRT_2                                          NaN
# dkfz_ATRT_3                                          NaN
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_146                                        NaN
# dkfz_ATRT_147                                        NaN
# dkfz_ATRT_148                                        NaN
# dkfz_ATRT_149                                        NaN
# dkfz_ATRT_150                                        NaN
#
#               Subgrouping based on H3K27Ac enhancer correlation  WGS cohort  \
# Sample Name
# dkfz_ATRT_1                                                 NaN         NaN
# dkfz_ATRT_2                                                 NaN         NaN
# dkfz_ATRT_3                                                 NaN         NaN
# dkfz_ATRT_4                                                 NaN         1.0
# dkfz_ATRT_5                                                 NaN         1.0
# ...                                                         ...         ...
# dkfz_ATRT_146                                               NaN         NaN
# dkfz_ATRT_147                                               NaN         NaN
# dkfz_ATRT_148                                               NaN         NaN
# dkfz_ATRT_149                                               NaN         NaN
# dkfz_ATRT_150                                               NaN         NaN
#
#                RNASequencing cohort  WGBS cohort  \
# Sample Name
# dkfz_ATRT_1                     NaN          NaN
# dkfz_ATRT_2                     NaN          NaN
# dkfz_ATRT_3                     NaN          NaN
# dkfz_ATRT_4                     NaN          1.0
# dkfz_ATRT_5                     1.0          1.0
# ...                             ...          ...
# dkfz_ATRT_146                   NaN          NaN
# dkfz_ATRT_147                   NaN          NaN
# dkfz_ATRT_148                   NaN          NaN
# dkfz_ATRT_149                   NaN          NaN
# dkfz_ATRT_150                   NaN          NaN
#
#                H3K27Ac ChIP Sequencing cohort  BRD4 ChIP Sequencing cohort  \
# Sample Name
# dkfz_ATRT_1                               NaN                          NaN
# dkfz_ATRT_2                               NaN                          NaN
# dkfz_ATRT_3                               NaN                          NaN
# dkfz_ATRT_4                               NaN                          NaN
# dkfz_ATRT_5                               NaN                          NaN
# ...                                       ...                          ...
# dkfz_ATRT_146                             NaN                          NaN
# dkfz_ATRT_147                             NaN                          NaN
# dkfz_ATRT_148                             NaN                          NaN
# dkfz_ATRT_149                             NaN                          NaN
# dkfz_ATRT_150                             NaN                          NaN
#
#                OTX2 ChIP Sequencing cohort  MITF ChIP Sequencing cohort  \
# Sample Name
# dkfz_ATRT_1                            NaN                          NaN
# dkfz_ATRT_2                            NaN                          NaN
# dkfz_ATRT_3                            NaN                          NaN
# dkfz_ATRT_4                            NaN                          NaN
# dkfz_ATRT_5                            NaN                          NaN
# ...                                    ...                          ...
# dkfz_ATRT_146                          NaN                          NaN
# dkfz_ATRT_147                          NaN                          NaN
# dkfz_ATRT_148                          NaN                          NaN
# dkfz_ATRT_149                          NaN                          NaN
# dkfz_ATRT_150                          NaN                          NaN
#
#               Gender (F= FeMale, M=Male)  Age at diagnosis  \
# Sample Name
# dkfz_ATRT_1                            F              2.00
# dkfz_ATRT_2                            M              2.00
# dkfz_ATRT_3                            F               NaN
# dkfz_ATRT_4                            M              4.00
# dkfz_ATRT_5                            M              4.00
# ...                                  ...               ...
# dkfz_ATRT_146                          M               NaN
# dkfz_ATRT_147                          M               NaN
# dkfz_ATRT_148                          F              0.90
# dkfz_ATRT_149                          M              0.25
# dkfz_ATRT_150                          F              0.80
#
#               Localization of primary tumor  \
# Sample Name
# dkfz_ATRT_1                  infratentorial
# dkfz_ATRT_2                  infratentorial
# dkfz_ATRT_3                  infratentorial
# dkfz_ATRT_4                  infratentorial
# dkfz_ATRT_5                  supratentorial
# ...                                     ...
# dkfz_ATRT_146                supratentorial
# dkfz_ATRT_147                supratentorial
# dkfz_ATRT_148                infratentorial
# dkfz_ATRT_149                supratentorial
# dkfz_ATRT_150                infratentorial
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing   \
# Sample Name
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                       delExon1_Exon9
# dkfz_ATRT_5                                    c.197C>A p.Ser66*
# ...                                                          ...
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
# dkfz_ATRT_148                                            SMARCA4
# dkfz_ATRT_149                                            SMARCA4
# dkfz_ATRT_150                                            SMARCA4
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing  \
# Sample Name
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                     delTBX1_NIPSNAP1
# dkfz_ATRT_5                                     delTBX1_NIPSNAP1
# ...                                                          ...
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
# dkfz_ATRT_148                                                NaN
# dkfz_ATRT_149                                                NaN
# dkfz_ATRT_150                                                NaN
#
#                Previosuly published (PMID number)         gsm
# Sample Name
# dkfz_ATRT_1                                   NaN  GSM1755170
# dkfz_ATRT_2                                   NaN  GSM1755171
# dkfz_ATRT_3                                   NaN  GSM1755172
# dkfz_ATRT_4                                   NaN  GSM1755173
# dkfz_ATRT_5                                   NaN  GSM1755174
# ...                                           ...         ...
# dkfz_ATRT_146                                 NaN  GSM2051701
# dkfz_ATRT_147                                 NaN  GSM2051702
# dkfz_ATRT_148                                 NaN  GSM2051673
# dkfz_ATRT_149                                 NaN  GSM2051674
# dkfz_ATRT_150                                 NaN  GSM2051675
#
# [150 rows x 19 columns]

# %%
# mc data
f = "./data/Johann_2016/Johann_2016_betas.h5ad"
adata = anndata.read(f)
adata
# Out:
# AnnData object with n_obs × n_vars = 485512 × 150

# %%
name_lookup = meta.reset_index().set_index('gsm')['Sample Name']
adata.var.index = [name_lookup.loc[samp.split('_')[0]] for samp in adata.var.index]
adata.var = meta.loc[adata.var.index]
adata.var
# Out:
#               Molecular Subgroup (Consensus)  \
# dkfz_ATRT_1                              SHH
# dkfz_ATRT_2                              SHH
# dkfz_ATRT_3                              SHH
# dkfz_ATRT_4                              MYC
# dkfz_ATRT_5                              SHH
# ...                                      ...
# dkfz_ATRT_143                            SHH
# dkfz_ATRT_144                            MYC
# dkfz_ATRT_145                            SHH
# dkfz_ATRT_146                            SHH
# dkfz_ATRT_147                            SHH
#
#               Subgrouping based on 450K methylation data  \
# dkfz_ATRT_1                                          SHH
# dkfz_ATRT_2                                          SHH
# dkfz_ATRT_3                                          SHH
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_143                                        SHH
# dkfz_ATRT_144                                        MYC
# dkfz_ATRT_145                                        SHH
# dkfz_ATRT_146                                        SHH
# dkfz_ATRT_147                                        SHH
#
#               Subrouping based on Affymetrix gene expression data  \
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                                  NaN
# dkfz_ATRT_4                                                  NaN
# dkfz_ATRT_5                                                  NaN
# ...                                                          ...
# dkfz_ATRT_143                                                NaN
# dkfz_ATRT_144                                                NaN
# dkfz_ATRT_145                                                NaN
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
#
#               Subgrouping based on WGBS methylation data  \
# dkfz_ATRT_1                                          NaN
# dkfz_ATRT_2                                          NaN
# dkfz_ATRT_3                                          NaN
# dkfz_ATRT_4                                          MYC
# dkfz_ATRT_5                                          SHH
# ...                                                  ...
# dkfz_ATRT_143                                        NaN
# dkfz_ATRT_144                                        NaN
# dkfz_ATRT_145                                        NaN
# dkfz_ATRT_146                                        NaN
# dkfz_ATRT_147                                        NaN
#
#               Subgrouping based on H3K27Ac enhancer correlation  WGS cohort  \
# dkfz_ATRT_1                                                 NaN         NaN
# dkfz_ATRT_2                                                 NaN         NaN
# dkfz_ATRT_3                                                 NaN         NaN
# dkfz_ATRT_4                                                 NaN         1.0
# dkfz_ATRT_5                                                 NaN         1.0
# ...                                                         ...         ...
# dkfz_ATRT_143                                               NaN         NaN
# dkfz_ATRT_144                                               NaN         NaN
# dkfz_ATRT_145                                               NaN         NaN
# dkfz_ATRT_146                                               NaN         NaN
# dkfz_ATRT_147                                               NaN         NaN
#
#                RNASequencing cohort  WGBS cohort  \
# dkfz_ATRT_1                     NaN          NaN
# dkfz_ATRT_2                     NaN          NaN
# dkfz_ATRT_3                     NaN          NaN
# dkfz_ATRT_4                     NaN          1.0
# dkfz_ATRT_5                     1.0          1.0
# ...                             ...          ...
# dkfz_ATRT_143                   NaN          NaN
# dkfz_ATRT_144                   NaN          NaN
# dkfz_ATRT_145                   NaN          NaN
# dkfz_ATRT_146                   NaN          NaN
# dkfz_ATRT_147                   NaN          NaN
#
#                H3K27Ac ChIP Sequencing cohort  BRD4 ChIP Sequencing cohort  \
# dkfz_ATRT_1                               NaN                          NaN
# dkfz_ATRT_2                               NaN                          NaN
# dkfz_ATRT_3                               NaN                          NaN
# dkfz_ATRT_4                               NaN                          NaN
# dkfz_ATRT_5                               NaN                          NaN
# ...                                       ...                          ...
# dkfz_ATRT_143                             NaN                          NaN
# dkfz_ATRT_144                             NaN                          NaN
# dkfz_ATRT_145                             NaN                          NaN
# dkfz_ATRT_146                             NaN                          NaN
# dkfz_ATRT_147                             NaN                          NaN
#
#                OTX2 ChIP Sequencing cohort  MITF ChIP Sequencing cohort  \
# dkfz_ATRT_1                            NaN                          NaN
# dkfz_ATRT_2                            NaN                          NaN
# dkfz_ATRT_3                            NaN                          NaN
# dkfz_ATRT_4                            NaN                          NaN
# dkfz_ATRT_5                            NaN                          NaN
# ...                                    ...                          ...
# dkfz_ATRT_143                          NaN                          NaN
# dkfz_ATRT_144                          NaN                          NaN
# dkfz_ATRT_145                          NaN                          NaN
# dkfz_ATRT_146                          NaN                          NaN
# dkfz_ATRT_147                          NaN                          NaN
#
#               Gender (F= FeMale, M=Male)  Age at diagnosis  \
# dkfz_ATRT_1                            F               2.0
# dkfz_ATRT_2                            M               2.0
# dkfz_ATRT_3                            F               NaN
# dkfz_ATRT_4                            M               4.0
# dkfz_ATRT_5                            M               4.0
# ...                                  ...               ...
# dkfz_ATRT_143                          M               NaN
# dkfz_ATRT_144                          F               NaN
# dkfz_ATRT_145                          M               NaN
# dkfz_ATRT_146                          M               NaN
# dkfz_ATRT_147                          M               NaN
#
#               Localization of primary tumor  \
# dkfz_ATRT_1                  infratentorial
# dkfz_ATRT_2                  infratentorial
# dkfz_ATRT_3                  infratentorial
# dkfz_ATRT_4                  infratentorial
# dkfz_ATRT_5                  supratentorial
# ...                                     ...
# dkfz_ATRT_143                infratentorial
# dkfz_ATRT_144                           NaN
# dkfz_ATRT_145                           NaN
# dkfz_ATRT_146                supratentorial
# dkfz_ATRT_147                supratentorial
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing   \
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                       delExon1_Exon9
# dkfz_ATRT_5                                    c.197C>A p.Ser66*
# ...                                                          ...
# dkfz_ATRT_143                                                NaN
# dkfz_ATRT_144                                                NaN
# dkfz_ATRT_145                                                NaN
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
#
#               Type of SMARCB1 mutation in MLPA/Sanger Sequencing  \
# dkfz_ATRT_1                                                  NaN
# dkfz_ATRT_2                                                  NaN
# dkfz_ATRT_3                                             delExon5
# dkfz_ATRT_4                                     delTBX1_NIPSNAP1
# dkfz_ATRT_5                                     delTBX1_NIPSNAP1
# ...                                                          ...
# dkfz_ATRT_143                                                NaN
# dkfz_ATRT_144                                                NaN
# dkfz_ATRT_145                                                NaN
# dkfz_ATRT_146                                                NaN
# dkfz_ATRT_147                                                NaN
#
#                Previosuly published (PMID number)         gsm
# dkfz_ATRT_1                                   NaN  GSM1755170
# dkfz_ATRT_2                                   NaN  GSM1755171
# dkfz_ATRT_3                                   NaN  GSM1755172
# dkfz_ATRT_4                                   NaN  GSM1755173
# dkfz_ATRT_5                                   NaN  GSM1755174
# ...                                           ...         ...
# dkfz_ATRT_143                                 NaN  GSM2051698
# dkfz_ATRT_144                                 NaN  GSM2051699
# dkfz_ATRT_145                                 NaN  GSM2051700
# dkfz_ATRT_146                                 NaN  GSM2051701
# dkfz_ATRT_147                                 NaN  GSM2051702
#
# [150 rows x 19 columns]

# %%
colors = sns.color_palette('Set1', 3)
colors
# Out:
# [(0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  (0.30196078431372547, 0.6862745098039216, 0.2901960784313726)]

# %%
palette = {
    'TYR': colors[0],
    'SHH': colors[1],
    'MYC': colors[2],
}

# %%
clsts = adata.var['Subgrouping based on 450K methylation data'].values
clsts
# Out:
# array(['SHH', 'SHH', 'SHH', 'MYC', 'SHH', 'TYR', 'SHH', 'TYR', 'SHH',
#        'TYR', 'SHH', 'SHH', 'MYC', 'TYR', 'SHH', 'TYR', 'SHH', 'SHH',
#        'SHH', 'SHH', 'SHH', 'TYR', 'TYR', 'TYR', 'TYR', 'MYC', 'MYC',
#        'TYR', 'SHH', 'TYR', 'SHH', 'SHH', 'TYR', 'TYR', 'SHH', 'SHH',
#        'MYC', 'SHH', 'SHH', 'TYR', 'MYC', 'SHH', 'MYC', 'SHH', 'SHH',
#        'MYC', 'TYR', 'TYR', 'MYC', 'MYC', 'SHH', 'TYR', 'MYC', 'SHH',
#        'SHH', 'SHH', 'TYR', 'TYR', 'MYC', 'SHH', 'TYR', 'TYR', 'MYC',
#        'MYC', 'MYC', 'TYR', 'TYR', 'SHH', 'MYC', 'TYR', 'MYC', 'SHH',
#        'TYR', 'SHH', 'SHH', 'TYR', 'MYC', 'TYR', 'SHH', 'TYR', 'SHH',
#        'MYC', 'TYR', 'TYR', 'TYR', 'SHH', 'TYR', 'MYC', 'MYC', 'MYC',
#        'MYC', 'TYR', 'TYR', 'TYR', 'TYR', 'MYC', 'SHH', 'TYR', 'TYR',
#        'TYR', 'TYR', 'SHH', 'SHH', 'MYC', 'SHH', 'SHH', 'SHH', 'SHH',
#        'SHH', 'TYR', 'SHH', 'TYR', 'SHH', 'SHH', 'MYC', 'SHH', 'SHH',
#        'SHH', 'MYC', 'SHH', 'SHH', 'SHH', 'SHH', 'SHH', 'MYC', 'MYC',
#        'TYR', 'SHH', 'TYR', 'TYR', 'SHH', 'TYR', 'TYR', 'TYR', 'TYR',
#        'MYC', 'SHH', 'TYR', 'MYC', 'TYR', 'MYC', 'SHH', 'TYR', 'SHH',
#        'SHH', 'SHH', 'MYC', 'SHH', 'SHH', 'SHH'], dtype=object)

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# Index: [cg00050873, cg00212031, cg00213748, cg00214611, cg00455876, cg01707559, cg02004872, cg02011394, cg02050847, cg02233190, cg02494853, cg02839557, cg02842889, cg03052502, cg03155755, cg03244189, cg03443143, cg03683899, cg03695421, cg03706273, cg03750315, cg03767353, cg04016144, cg04023335, cg04042030, cg04303809, cg04448376, cg04462340, cg04689676, cg04792227, cg04840163, cg04964672, cg05213048, cg05230942, cg05480730, cg05544622, cg05621349, cg05865243, cg05890011, cg06322277, cg06479204, cg07731488, cg07747963, cg07939587, cg08242338, cg08265308, cg08921682, cg09350919, cg09460641, cg09856092, cg10076560, cg10213302, cg10252249, cg10267609, cg10363397, cg10698069, cg10841270, cg11131351, cg13268984, cg13851368, cg14180491, cg14210405, cg14466580, cg14741114, cg15027426, cg15295597, cg15329860, cg15345074, cg15422579, cg15429127, cg15563434, cg15682806, cg15682993, cg15746461, cg15810474, cg15935877, cg17834650, cg17837162, cg18032798, cg18077436, cg18188392, cg25032547, cg25071634, cg25427172, cg25518695, cg25705492, cg25756647, cg26058907, cg26517491, cg26520468, cg26983430, cg26983535, cg27049643, cg27433982, cg27539833, cg00008945, cg00011200, cg00011891, cg00014152, cg00016522, ...]
#
# [485512 rows x 0 columns]

# %%
adata.X.shape
# Out:
# (485512, 150)

# %%
ftrs = adata.X
print(ftrs.shape)
ftrs = ftrs[~np.any(np.isnan(ftrs), axis=1)]
print(ftrs.shape)

sites_std = ftrs.std(axis=1)
th = np.sort(sites_std)[::-1][7500]
print(th)
hvftrs = ftrs[sites_std > th]
print(hvftrs.shape)
# Out:
# (485512, 150)
# (484716, 150)
# 0.2376051
# (7500, 150)

# %%
sns.histplot(sites_std)
plt.axvline(th, color='k')
plt.title(f"Top {len(hvftrs)} sites with std > {th:.3g}")
# Out:
# Text(0.5, 1.0, 'Top 7500 sites with std > 0.238')

# %%
g = sns.clustermap(hvftrs, cmap='coolwarm', col_colors=pd.Series(clsts).map(palette).values)
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# annotate cg sites
# overlap mammal 320

# %%
sites_comm = np.load('./data/m320k_i450k_overlap_5559.npy', allow_pickle=True)
print(sites_comm.shape)
sites_comm = np.intersect1d(sites_comm, adata.obs.index.values)
print(sites_comm.shape)
sites_comm
# Out:
# (5559,)
# (5500,)
# array(['cg00000165', 'cg00001364', 'cg00001582', ..., 'ch.13.39564907R',
#        'ch.2.30415474F', 'ch.3.741789F'], dtype=object)

# %%
adata.obs.loc[sites_comm]
# Out:
# Empty DataFrame
# Columns: []
# Index: [cg00000165, cg00001364, cg00001582, cg00003994, cg00005112, cg00010445, cg00015319, cg00017842, cg00031896, cg00036788, cg00037013, cg00037952, cg00049718, cg00051782, cg00056578, cg00058449, cg00060304, cg00065957, cg00066554, cg00067884, cg00073460, cg00073543, cg00075967, cg00079056, cg00079224, cg00083937, cg00084577, cg00091349, cg00091693, cg00091964, cg00096922, cg00103299, cg00107682, cg00109076, cg00109300, cg00111333, cg00113096, cg00113951, cg00116234, cg00146676, cg00147638, cg00149213, cg00158333, cg00159243, cg00167491, cg00168942, cg00186529, cg00187380, cg00194126, cg00194146, cg00197058, cg00211337, cg00216659, cg00218447, cg00219921, cg00230271, cg00247020, cg00256932, cg00257455, cg00261781, cg00271154, cg00272971, cg00282704, cg00287915, cg00297075, cg00310215, cg00314427, cg00318947, cg00321644, cg00323965, cg00324097, cg00324161, cg00331096, cg00335286, cg00338702, cg00343092, cg00343217, cg00347775, cg00350702, cg00363312, cg00366435, cg00367497, cg00369613, cg00369852, cg00371107, cg00374717, cg00399596, cg00401433, cg00403457, cg00405803, cg00409684, cg00410898, cg00412772, cg00412805, cg00419757, cg00426659, cg00431549, cg00436603, cg00438946, cg00439981, ...]
#
# [5500 rows x 0 columns]

# %%
adatasub = adata[sites_comm]
adatasub
# Out:
# View of AnnData object with n_obs × n_vars = 5500 × 150
#     var: 'Molecular Subgroup (Consensus)', 'Subgrouping based on 450K methylation data', 'Subrouping based on Affymetrix gene expression data', 'Subgrouping based on WGBS methylation data', 'Subgrouping based on H3K27Ac enhancer correlation', 'WGS cohort', 'RNASequencing cohort', 'WGBS cohort', 'H3K27Ac ChIP Sequencing cohort', 'BRD4 ChIP Sequencing cohort', 'OTX2 ChIP Sequencing cohort', 'MITF ChIP Sequencing cohort', 'Gender (F= FeMale, M=Male)', 'Age at diagnosis', 'Localization of primary tumor', 'Type of SMARCB1 mutation in MLPA/Sanger Sequencing ', 'Type of SMARCB1 mutation in MLPA/Sanger Sequencing', 'Previosuly published (PMID number)', 'gsm'

# %%
ftrs = adatasub.X
print(ftrs.shape)
ftrs = ftrs[~np.any(np.isnan(ftrs), axis=1)]
print(ftrs.shape)

sites_std = ftrs.std(axis=1)
# th = np.sort(sites_std)[::-1][7500]
# print(th)
th = 0.2
hvftrs = ftrs[sites_std > th]
print(hvftrs.shape)
# Out:
# (5500, 150)
# (5489, 150)
# (466, 150)

# %%
sns.histplot(sites_std)
plt.axvline(th, color='k')
plt.title(f"Top {len(hvftrs)} sites with std > {th}")
# Out:
# Text(0.5, 1.0, 'Top 466 sites with std > 0.2')

# %%
g = sns.clustermap(hvftrs, cmap='coolwarm', col_colors=pd.Series(clsts).map(palette).values)
# Out:
# /home/fangming/anaconda3/envs/routine/lib/python3.10/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# annotate sites
